# %% [markdown]
# # Basic Analysis

# %%
import pandas as pd

# %%
oo = pd.read_csv('M:/python/Python_Course_DS_beginners/Day-2/data/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### value_counts()

# %%
oo.Athlete.value_counts()
# Out:
# LATYNINA, Larisa                  18
# PHELPS, Michael                   16
# ANDRIANOV, Nikolay                15
# ONO, Takashi                      13
# MANGIAROTTI, Edoardo              13
# SHAKHLIN, Boris                   13
# NURMI, Paavo                      12
# KATO, Sawao                       12
# FISCHER, Birgit                   12
# TORRES, Dara                      12
# NEMOV, Alexei                     12
# THOMPSON, Jenny                   12
# OSBURN, Carl Townsend             11
# CHUKARIN, Viktor Ivanovich        11
# CASLAVSKA, Vera                   11
# SPITZ, Mark                       11
# BIONDI, Matthew                   11
# COUGHLIN, Natalie                 11
# SCHERBO, Vitaly                   10
# ASTAKHOVA, Polina                 10
# HALL, Gary Jr.                    10
# DITYATIN, Aleksandr               10
# NAKAYAMA, Akinori                 10
# GEREVICH, Aladar                  10
# VAN ALMSICK, Franziska            10
# ...

# %%
oo.Gender.value_counts(ascending=True,dropna=False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# ### sort_values()

# %%
ath = oo.Discipline.sort_values()
ath
# Out:
# 27534            Archery
# 2947             Archery
# 2946             Archery
# 2945             Archery
# 2944             Archery
# 2943             Archery
# 2942             Archery
# 2941             Archery
# 2940             Archery
# 2939             Archery
# 2938             Archery
# 2937             Archery
# 2936             Archery
# 2935             Archery
# 2934             Archery
# 2933             Archery
# 2932             Archery
# 2931             Archery
# 2930             Archery
# 2929             Archery
# 2928             Archery
# 2927             Archery
# 2948             Archery
# 2949             Archery
# 2950             Archery
# 2951             Archery
# 2974             Archery
# 2972             Archery
# 2971             Archery
# 2970             Archery
#               ...
# 9771     Wrestling Gre-R
# 9770     Wrestling Gre-R
# 27153    Wrestling Gre-R
# 27154    Wrestling Gre-R
# 27155    Wrestling Gre-R
# 27156    Wrestling Gre-R
# ...

# %%
oo.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %%
oo.sort_values(['Edition','NOC'])
# Out:
#           City  Edition          Sport       Discipline  \
# 18      Athens     1896      Athletics        Athletics
# 24      Athens     1896      Athletics        Athletics
# 1       Athens     1896       Aquatics         Swimming
# 9       Athens     1896       Aquatics         Swimming
# 53      Athens     1896        Cycling    Cycling Track
# 56      Athens     1896        Cycling    Cycling Track
# 58      Athens     1896        Cycling    Cycling Track
# 69      Athens     1896        Fencing          Fencing
# 120     Athens     1896       Shooting         Shooting
# 125     Athens     1896       Shooting         Shooting
# 129     Athens     1896       Shooting         Shooting
# 144     Athens     1896  Weightlifting    Weightlifting
# 146     Athens     1896  Weightlifting    Weightlifting
# 17      Athens     1896      Athletics        Athletics
# 47      Athens     1896      Athletics        Athletics
# 51      Athens     1896        Cycling    Cycling Track
# ...

# %% [markdown]
# ### Boolean indexing

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %% [markdown]
# ### String handling

# %%
oo[oo.Athlete.str.ToUpper()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-00b62c681351> in <module>()
# ----> 1 oo[oo.Athlete.str.toUpper()]
#
# AttributeError: 'StringMethods' object has no attribute 'toUpper'
